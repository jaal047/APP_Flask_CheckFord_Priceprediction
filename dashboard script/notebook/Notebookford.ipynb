# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### Import original dataset dari kaggle (https://www.kaggle.com/aishwaryamuthukumar/cars-dataset-audi-bmw-ford-hyundai-skoda-vw)

# %%
#cars_dataset
cars_dataset = pd.read_csv('cars_dataset.csv')
cars_dataset.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %%
#head with unique values
cars_dataset.head(10)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
# 5    A1  2016  13900    Automatic    32260   Petrol   30.0  58.9         1.4
# 6    A6  2016  13250    Automatic    76788   Diesel   30.0  61.4         2.0
# 7    A4  2016  11750       Manual    75185   Diesel   20.0  70.6         2.0
# 8    A3  2015  10200       Manual    46112   Petrol   20.0  60.1         1.4
# 9    A1  2016  12000       Manual    22451   Petrol   30.0  55.4         1.4
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi
# 5  audi
# 6  audi
# 7  audi
# 8  audi
# 9  audi

# %%
#datatype
cars_dataset.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax             float64
# mpg             float64
# engineSize      float64
# Make             object
# dtype: object

# %% [markdown]
# ### import ford.csv

# %%
df = pd.read_csv("Ford.csv", delimiter = ";")
df
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150.0  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150.0  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150.0  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145.0  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145.0  48.7
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 17959   Fiesta  2016   7999       Manual    31348   Petrol  125.0  54.3
# 17960    B-MAX  2017   8999       Manual    16700   Petrol  150.0  47.1
# 17961    B-MAX  2014   7499       Manual    40700   Petrol   30.0  57.7
# 17962    Focus  2015   9999       Manual     7010   Diesel   20.0  67.3
# 17963       KA  2018   8299       Manual     5007   Petrol  145.0  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17959         1.2
# 17960         1.4
# 17961         1.0
# 17962         1.6
# 17963         1.2
#
# [17964 rows x 9 columns]

# %%
#show model and price only
df_model = df[['model', 'price',"mpg","tax","engineSize","mileage"]]

# %%
#find df_model mean
df_model
# Out:
#          model  price   mpg    tax  engineSize  mileage
# 0       Fiesta  12000  57.7  150.0         1.0    15944
# 1        Focus  14000  57.7  150.0         1.0     9083
# 2        Focus  13000  57.7  150.0         1.0    12456
# 3       Fiesta  17500  40.3  145.0         1.5    10460
# 4       Fiesta  16500  48.7  145.0         1.0     1482
# ...        ...    ...   ...    ...         ...      ...
# 17959   Fiesta   7999  54.3  125.0         1.2    31348
# 17960    B-MAX   8999  47.1  150.0         1.4    16700
# 17961    B-MAX   7499  57.7   30.0         1.0    40700
# 17962    Focus   9999  67.3   20.0         1.6     7010
# 17963       KA   8299  57.7  145.0         1.2     5007
#
# [17964 rows x 6 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
#find each price mean
df_model = df_model.groupby('model').mean()

# %%
df_model
# Out:
#                                price        mpg         tax  engineSize  \
# model
#  B-MAX                   8287.526761  55.678592   90.957746    1.316901
#  C-MAX                   9914.567219  59.508840   71.712707    1.407366
#  EcoSport               12499.268591  53.093526  136.342957    1.108924
#  Edge                   22810.500000  46.150962  156.899038    2.000000
#  Escort                  3000.000000  34.400000  265.000000    1.800000
#  Fiesta                 10196.862569  60.980201  100.861806    1.098032
#  Focus                  13185.882956  60.089385  111.156277    1.361421
#  Fusion                  2555.812500  45.393750  183.750000    1.487500
#  Galaxy                 17841.872807  53.347807  145.855263    1.978070
#  Grand C-MAX            10881.574899  58.367206   72.834008    1.407287
#  Grand Tourneo Connect  14874.915254  60.172881  114.152542    1.510169
#  KA                      5186.125628  56.092462   56.180905    1.168844
#  Ka+                     8707.856874  53.329755  134.830508    1.191525
#  Kuga                   15823.472360  51.677528  145.719101    1.808764
#  Mondeo                 12305.709125  60.034030   99.619772    1.894297
#  Mustang                34631.263158  24.271930  210.614035    4.384211
#  Puma                   21447.250000  50.136250  148.000000    1.003750
#  Ranger                 14495.000000  28.300000  240.000000    3.200000
#  S-MAX                  17720.226351  51.907432  150.388514    1.959122
#  Streetka                1924.500000  35.550000  280.000000    1.600000
#  Tourneo Connect        13805.818182  58.148485  108.787879    1.493939
#  Tourneo Custom         21165.985507  38.611594  164.347826    2.008696
#  Transit Tourneo        12450.000000  42.200000  235.000000    2.200000
#
#                              mileage
# model
#  B-MAX                  28131.735211
#  C-MAX                  28456.979742
#  EcoSport               16469.806649
#  Edge                   21769.495192
#  Escort                 50000.000000
#  Fiesta                 21679.115619
#  Focus                  23735.274412
#  Fusion                 65888.812500
#  Galaxy                 32994.956140
#  Grand C-MAX            27882.663968
#  Grand Tourneo Connect  23602.389831
#  KA                     35604.567839
#  Ka+                    11602.276836
#  Kuga                   23707.501124
#  Mondeo                 45834.733840
#  Mustang                 9480.140351
#  Puma                    3839.887500
#  Ranger                 88000.000000
#  S-MAX                  31896.280405
#  Streetka               68527.500000
#  Tourneo Connect        24458.303030
#  Tourneo Custom         21791.347826
#  Transit Tourneo        19496.000000

# %%
#save to xlsx
df_model.to_excel("ford_model.xlsx")

# %%
#scatter engineSize vs price
df_model.plot(kind='scatter', x='tax', y='price')
# Out:
# <AxesSubplot:xlabel='tax', ylabel='price'>

# %%
# Split X and y
X = df.drop(['model', 'price'], axis=1)
y = df['price']

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.645450 -0.718751  0.300468 -0.021489   -0.139217
# price       0.645450  1.000000 -0.530678  0.406963 -0.346564    0.411181
# mileage    -0.718751 -0.530678  1.000000 -0.260718  0.120227    0.215007
# tax         0.300468  0.406963 -0.260718  1.000000 -0.502952    0.184313
# mpg        -0.021489 -0.346564  0.120227 -0.502952  1.000000   -0.260534
# engineSize -0.139217  0.411181  0.215007  0.184313 -0.260534    1.000000

# %%
# Create dummies for categorical variables

# subset all categorical variables
cars_categorical = X.select_dtypes(include=['object'])
# convert into dummies
cars_dummies = pd.get_dummies(cars_categorical, drop_first=True)
# drop categorical variables 
X = X.drop(list(cars_categorical.columns), axis=1)
# concat dummy variables with X
X = pd.concat([X, cars_dummies], axis=1)
X
# Out:
#        year  mileage    tax   mpg  engineSize  transmission_Manual  \
# 0      2017    15944  150.0  57.7         1.0                    0
# 1      2018     9083  150.0  57.7         1.0                    1
# 2      2017    12456  150.0  57.7         1.0                    1
# 3      2019    10460  145.0  40.3         1.5                    1
# 4      2019     1482  145.0  48.7         1.0                    0
# ...     ...      ...    ...   ...         ...                  ...
# 17959  2016    31348  125.0  54.3         1.2                    1
# 17960  2017    16700  150.0  47.1         1.4                    1
# 17961  2014    40700   30.0  57.7         1.0                    1
# 17962  2015     7010   20.0  67.3         1.6                    1
# 17963  2018     5007  145.0  57.7         1.2                    1
#
#        transmission_Semi-Auto  fuelType_Electric  fuelType_Hybrid  \
# 0                           0                  0                0
# 1                           0                  0                0
# 2                           0                  0                0
# 3                           0                  0                0
# 4                           0                  0                0
# ...                       ...                ...              ...
# 17959                       0                  0                0
# 17960                       0                  0                0
# 17961                       0                  0                0
# 17962                       0                  0                0
# 17963                       0                  0                0
#
#        fuelType_Other  fuelType_Petrol
# 0                   0                1
# 1                   0                1
# 2                   0                1
# 3                   0                1
# 4                   0                1
# ...               ...              ...
# 17959               0                1
# 17960               0                1
# 17961               0                1
# 17962               0                0
# 17963               0                1
#
# [17964 rows x 11 columns]

# %%
# Scale the features

# Store column names since the column names will be lost after scaling
cols = X.columns

# Scale the features and convert it back to a dataframe
X = pd.DataFrame(scale(X))

# Write in the column names again
X.columns = cols
X.columns
# Out:
# Index(['year', 'mileage', 'tax', 'mpg', 'engineSize', 'transmission_Manual',
#        'transmission_Semi-Auto', 'fuelType_Electric', 'fuelType_Hybrid',
#        'fuelType_Other', 'fuelType_Petrol'],
#       dtype='object')

# %% [markdown]
# ### Applied Linear Regression menggunakan sklearn

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.8,
                                                    test_size = 0.2, random_state=125)

# %%
# Instantiate the model
lm = LinearRegression()

# Fit the model
lm.fit(X_train, y_train)

# Make prediction
y_pred = lm.predict(X_test)

# Performance metrics
lr_r2= r2_score(y_test, y_pred)
lr_mae = mean_absolute_error(y_test, y_pred)

# Show the metrics
print("Linear Regression R2: ", lr_r2)
print("Linear Regression MAE: ", lr_mae)
# Out:
# Linear Regression R2:  0.7500172386036711
# Linear Regression MAE:  1781.2119117335105

# %%
#melakukan analisis regresi
import statsmodels.api as sm
from scipy import stats

#summary
X = sm.add_constant(X_train)
result = sm.OLS(y_train, X).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     3879.
# Date:                Sat, 08 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:49:58   Log-Likelihood:            -1.3202e+05
# No. Observations:               14371   AIC:                         2.641e+05
# Df Residuals:                   14359   BIC:                         2.642e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   1.227e+04     19.723    621.988      0.000    1.22e+04    1.23e+04
# year                    2553.3613     29.787     85.720      0.000    2494.974    2611.748
# mileage                -1063.9241     29.603    -35.940      0.000   -1121.949   -1005.899
# tax                       43.4334     24.481      1.774      0.076      -4.552      91.419
# mpg                    -1124.0227     30.167    -37.261      0.000   -1183.153   -1064.892
# engineSize              1749.6702     34.324     50.975      0.000    1682.391    1816.949
# transmission_Manual     -296.5486     27.650    -10.725      0.000    -350.746    -242.351
# transmission_Semi-Auto   -87.1590     26.057     -3.345      0.001    -138.233     -36.085
# fuelType_Electric         10.5296     17.669      0.596      0.551     -24.104      45.163
# fuelType_Hybrid          236.5504     19.992     11.832      0.000     197.364     275.737
# fuelType_Other             3.4200     17.654      0.194      0.846     -31.185      38.025
# fuelType_Petrol         -652.5463     34.725    -18.792      0.000    -720.612    -584.480
# ==============================================================================
# Omnibus:                     3417.426   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33990.751
# Skew:                           0.857   Prob(JB):                         0.00
# Kurtosis:                      10.337   Cond. No.                         3.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Menghapus Variabel yang memiliki p value lebih dari alpha (0,05)

# %%
# Split X and y
X = df.drop(['model', 'price', 'tax'], axis=1)
y = df['price']

# %%
# Create dummies for categorical variables

# subset all categorical variables
cars_categorical = X.select_dtypes(include=['object'])
# convert into dummies
cars_dummies = pd.get_dummies(cars_categorical, drop_first=True)
# drop categorical variables 
X = X.drop(list(cars_categorical.columns), axis=1)
# concat dummy variables with X
X = pd.concat([X, cars_dummies], axis=1)
X
# Out:
#        year  mileage   mpg  engineSize  transmission_Manual  \
# 0      2017    15944  57.7         1.0                    0
# 1      2018     9083  57.7         1.0                    1
# 2      2017    12456  57.7         1.0                    1
# 3      2019    10460  40.3         1.5                    1
# 4      2019     1482  48.7         1.0                    0
# ...     ...      ...   ...         ...                  ...
# 17959  2016    31348  54.3         1.2                    1
# 17960  2017    16700  47.1         1.4                    1
# 17961  2014    40700  57.7         1.0                    1
# 17962  2015     7010  67.3         1.6                    1
# 17963  2018     5007  57.7         1.2                    1
#
#        transmission_Semi-Auto  fuelType_Electric  fuelType_Hybrid  \
# 0                           0                  0                0
# 1                           0                  0                0
# 2                           0                  0                0
# 3                           0                  0                0
# 4                           0                  0                0
# ...                       ...                ...              ...
# 17959                       0                  0                0
# 17960                       0                  0                0
# 17961                       0                  0                0
# 17962                       0                  0                0
# 17963                       0                  0                0
#
#        fuelType_Other  fuelType_Petrol
# 0                   0                1
# 1                   0                1
# 2                   0                1
# 3                   0                1
# 4                   0                1
# ...               ...              ...
# 17959               0                1
# 17960               0                1
# 17961               0                1
# 17962               0                0
# 17963               0                1
#
# [17964 rows x 10 columns]

# %%
X = X.drop(['fuelType_Electric', 'fuelType_Other'], axis=1)
X
# Out:
#        year  mileage   mpg  engineSize  transmission_Manual  \
# 0      2017    15944  57.7         1.0                    0
# 1      2018     9083  57.7         1.0                    1
# 2      2017    12456  57.7         1.0                    1
# 3      2019    10460  40.3         1.5                    1
# 4      2019     1482  48.7         1.0                    0
# ...     ...      ...   ...         ...                  ...
# 17959  2016    31348  54.3         1.2                    1
# 17960  2017    16700  47.1         1.4                    1
# 17961  2014    40700  57.7         1.0                    1
# 17962  2015     7010  67.3         1.6                    1
# 17963  2018     5007  57.7         1.2                    1
#
#        transmission_Semi-Auto  fuelType_Hybrid  fuelType_Petrol
# 0                           0                0                1
# 1                           0                0                1
# 2                           0                0                1
# 3                           0                0                1
# 4                           0                0                1
# ...                       ...              ...              ...
# 17959                       0                0                1
# 17960                       0                0                1
# 17961                       0                0                1
# 17962                       0                0                0
# 17963                       0                0                1
#
# [17964 rows x 8 columns]

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.8,
                                                    test_size = 0.2, random_state=125)

# %%
# Instantiate the model
lm = LinearRegression()

# Fit the model
lm.fit(X_train, y_train)

# Make prediction
y_pred = lm.predict(X_test)

# Performance metrics
lr_r2= r2_score(y_test, y_pred)
lr_mae = mean_absolute_error(y_test, y_pred)

# Show the metrics
print("Linear Regression R2: ", lr_r2)
print("Linear Regression MAE: ", lr_mae)
# Out:
# Linear Regression R2:  0.7500636883650983
# Linear Regression MAE:  1779.7706552314705

# %%
#melakukan analisis regresi
import statsmodels.api as sm
from scipy import stats

#summary
X = sm.add_constant(X_train)
result = sm.OLS(y_train, X).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     5333.
# Date:                Sat, 08 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:49:59   Log-Likelihood:            -1.3202e+05
# No. Observations:               14371   AIC:                         2.641e+05
# Df Residuals:                   14362   BIC:                         2.641e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   -2.54e+06   2.88e+04    -88.219      0.000    -2.6e+06   -2.48e+06
# year                    1267.2680     14.253     88.910      0.000    1239.330    1295.206
# mileage                   -0.0547      0.002    -35.976      0.000      -0.058      -0.052
# mpg                     -112.7774      2.797    -40.327      0.000    -118.259    -107.296
# engineSize              4064.2016     78.817     51.565      0.000    3909.711    4218.693
# transmission_Manual     -870.2704     80.468    -10.815      0.000   -1027.997    -712.544
# transmission_Semi-Auto  -372.3064    109.181     -3.410      0.001    -586.315    -158.298
# fuelType_Hybrid         6787.2113    571.380     11.879      0.000    5667.232    7907.190
# fuelType_Petrol        -1388.4468     74.185    -18.716      0.000   -1533.859   -1243.034
# ==============================================================================
# Omnibus:                     3429.120   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34199.425
# Skew:                           0.860   Prob(JB):                         0.00
# Kurtosis:                      10.359   Cond. No.                     4.46e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#save model with joblib
import joblib
save_model = joblib.dump(lm, 'model.pkl')
save_model
# Out:
# ['model.pkl']

# %%
#print first 5 rows of X_test
y = X_test.head()
y
# Out:
#        year  mileage   mpg  engineSize  transmission_Manual  \
# 6079   2016    17870  62.8         1.0                    1
# 13353  2018    15158  65.7         1.0                    1
# 8600   2018     5402  64.2         1.1                    1
# 10006  2017    28056  60.1         2.0                    1
# 4023   2018    10388  57.7         1.2                    1
#
#        transmission_Semi-Auto  fuelType_Hybrid  fuelType_Petrol
# 6079                        0                0                1
# 13353                       0                0                1
# 8600                        0                0                1
# 10006                       0                0                0
# 4023                        0                0                1

# %%
#predict lm
y_pred
# Out:
# array([ 8943.73340436, 11299.51797037, 12408.60141314, ...,
#         5744.41238228, 15834.77369291,  7716.18607907])

# %%
#match with y_test
y_test
# Out:
# 6079      8999
# 13353    11500
# 8600     10390
# 10006    14495
# 4023      8750
#          ...
# 5874     19110
# 4629      8498
# 14690     5499
# 14737    15999
# 15899     7599
# Name: price, Length: 3593, dtype: int64

# %%
#make histogram of x and y
plt.hist(y_test, bins=20, alpha=0.5, label='y_test')
plt.hist(y_pred, bins=20, alpha=0.5, label='y_pred')
plt.legend(loc='upper right')
plt.show()
